# %%
import os
os.listdir('.')
f = open('SCUM-for-album.txt')
raw = f.read()

# %%
path = find('doc-analysis/scum-Aceanger/SCUM-for-album.txt')
raw = open(path, 'rU').read()

# %%
from projectPython import *

# %%
import projectPython
os.listdir('.')

# %%
import os
os.listdir('.')

# %%
f = open('Atrocity.txt')
raw = f.read()

# %%
path = find('scum-Aceanger/SCUM-for-album.txt')

# %%
f = open ('scum-Aceanger/SCUM-for-album.txt')
raw = f.read()
scum = 'SCUM-for-album.txt'
#sorted(set(scum))
def lexical_diversity(text):
    return len(set(text)) / len(text)
def percentage(count, total):
    return 100 * count / total
lexical_diversity(scum)

# %%
import scum_aceAnger
f = open('scum_aceAnger/SCUM-for-album.txt')
f = open('scum_aceAnger/Song_asexualAnger.txt')
raw = f.read()
scum = 'SCUM-for-album.txt'
anger = 'Song_asexualAnger.txt'
sorted(set(anger))

# %% [markdown]
# below I sucessfully attempted to import every file from the "scum_aceAnger" file without importing each indivdual file by itself

# %%
# Source - https://stackoverflow.com/a/50626064
# Posted by Andrei
# Retrieved 2026-04-30, License - CC BY-SA 4.0

import os,glob
folder_path = 'scum_aceAnger'
for filename in glob.glob(os.path.join(folder_path, '*.txt')):
  with open(filename, 'r') as f:
    text = f.read()
    print (filename)
    print (len(text))

whole_file = 'scum_aceAnger'

def lexical_diversity(text):
    return len(set(text)) / len(text)
def percentage(count, total):
    return 100 * count / total
lexical_diversity(whole_file)

# %% [markdown]
# the next two cells I'm trying to process the python with all my files

# %%
import os,glob
folder_path = 'scum_aceAnger'
for filename in glob.glob(os.path.join(folder_path, '*.txt')):
  with open(filename, 'r') as f:
    text = f.read()
    print (filename)
    print (len(text))

import os,glob
folder_path = '1880-1930'
    #adding | to indicate "or"
for filename in glob.glob(os.path.join(folder_path, '*.txt')):
  with open(filename, 'r') as f:
    text = f.read()
    print (filename)
    print (len(text))

# %% [markdown]
# I was able to it to process all of my texts. I'm now trying to imput a plot for this

# %%
import os,glob
folder_path = 'doc_analysis'
for filename in glob.glob(os.path.join(folder_path)):
  with open(filename, 'r') as f:
    text = f.read()
    print (filename)
    print (len(text))

whole_file = 'doc_analysis'

import matplotlib
import matplotlib.pyplot as plt


plt.plot(range(10))
plt.show()
whole_file.dispersion_plot(['celibacy', 'asexual', 'perversion', 'disorder', 'queer', 'homosexuality'])
plt.show()



def lexical_diversity(text):
    return len(set(text)) / len(text)
def percentage(count, total):
    return 100 * count / total
lexical_diversity(whole_file)

# %% [markdown]
# testing out a dispersion plot by using scum.

# %%
import nltk
import matplotlib
import matplotlib.pyplot as plt

with open("SCUM-for-album.txt", 'r', encoding='utf-8') as file:
    text=file.read() #ebb: This unpacks the text from the file
    textTokens=text.split()
lowerCaseTokens = [w.lower() for w in textTokens]
print(set(lowerCaseTokens))

scumTextObject = nltk.Text(lowerCaseTokens)

print(f"scum as NLTK Text Object = {scumTextObject}")

scumTextObject.dispersion_plot(["men", "sex", "penis", "pussy", "girl", "woman"])
plt.show()
# Out:
# {'either', 'everyone', 'appreciated', 'compulsive', 'brute', 'figured', 'have', 'army,', 'quiet,', 'conducive', 'quarters.', 'definition', 'acting', 'emotionally', 'himself:', 'causing', 'association', 'politeness', 'animal,', 'sex,', 'concerts,', 'guard', 'smallest', 'tribe,', 'seems', 'rapidly.', 'automation,', 'man;', 'diseases', 'approval-seeking', 'by,', 'becoming', 'rightness', 'dares', 'place;', 'depth', 'around...', 'animals', 'conventional,', 'togetherness', '-', 'queen,', 'things,', 'sensations.', 'looks', 'relating', "`finer'", 'prattle', 'arouse', 'ancients,', 'riots,', 'conscious', 'decline', 'work,', 'strikes,', 'until', 'disapproval,', 'ungroovy', 'available', 'scurries', 'scene,', 'women)', 'surprising', 'forth', 'fulfillment', 'me)', 'could', 'mean.', 'male.', 'sensibilities', 'realizing', 'thrill..', 'bad', 'only.', 'stepped', 'pool', 'jennings),', 'please', 'purpose', "isn't.", 'incomprehensibility,', 'rigidity,', 'anything', 'discover,', 'spirits', 'plays', 'diversion', 'philosophical', 'nice,', 'seen', 'movie', 'snaggle-toothed', 'psychiatrists', 'individuality', 'editors,', 'enforce', 'ever,', 'toadies,', "don't", 'invest', 'cultivate', 'training', 'delight', 'faggots', 'or,', 'unnatural', 'large', 'studios.', 'educational', 'part,', 'unable', 'third,', "`sympathetic'", 'fair', 'academic', '(love):', 'additional', 'teeth,', 'intrusion', 'awe', 'communion', 'advertising', 'ends)', 'another.', 'mind', 'peace', 'clear', 'self.', 'chairmen', 'russia.', 'manipulate,', 'painting.', 'not,', 'approves', 'care.', "daddy's;", 'swinging,', 'grasp', 'treacherous,', 'couples', 'remain', 'say.', 'version', 'moreover,', 'wit', 'function', 'farming,', 'life,', 'or', 'when', 'class,', 'government:', 'simple', 'booster', "he'll", 'professionally,', 'justify', 'isolation', 'scum,', 'rapport,', 'shame,', '300', 'enable', 'bottom,', 'in', 'mama', 'prevent', 'evolved', 'bore,', "`respecting'", 'come', 'been', 'nation', 'move,', 'expensiveness,', 'sperm.', 'role', "couldn't", 'cancer', 'discussion,', 'world', 'though,', "`artistic'", 'blob.', 'units.', '(or,', 'male,', 'nicer', 'cosmos,', 'sterile,', 'peddling', 'passivity):', 'relaxed,', 'prey', 'cowardice,', 'suburbs', 'delusion', 'violating', 'violation', 'used.', "`manly'", 'good', 'lot', 'non-participating,', 'their', 'emotion', 'pay', 'activity,', 'hacking', 'loves', '(mama)', 'sanity.', 'consist', 'chromosomes.', 'superior', 'seldom', 'mess', 'artists;', 'happiness;', 'religious', 'left', 'aspect', 'empty', 'makes', 'enjoying', 'stringing.', 'talk,', 'operators', '(lbj', 'demonstrate,', 'dimly', 'hospitals.', 'fleeting', 'marriage', 'universe;', 'out.', 'detail', 'make', 'excitement,', 'that', "man').", 'screen', 'impatient;', 'screwing,', 'educate', 'limited,', 'waste', 'cover', 'fag,', '2000', 'over', 'several', 'niceness,', 'paralyzing', 'uk', 'removed', 'sufficiently', 'note:', 'being,', 'change', 'profound', 'satisfying', 'agenda', 'reproduction.', 'that,', 'attainment', 'why', 'angry,', 'salvation', 'baby', 'potential', 'directed', 'except', 'early', 'arousal', 'out),', 'dominate,', 'action,', 'conversation:', 'before', 'fat,', 'consequently,', 'philosophers,', 'potentialities', 'security', 'thrilling', 'friendly', 'asexuality.', 'bust', 'http://www.bcn.net/~jpiazzo/scum.htm', 'cow', 'class', 'always', 'discovered', 'a', 'exists,', 'intrigues', 'perceptions,', 'flatter', 'asshole', 'veneration', 'shots.', 'mass', 'correlate', 'unnecessary', 'preceding', 'proficiency,', 'turn', 'therefore', 'play', 'agents', 'stilted', 'affluence', 'knows', 'will', 'cowardly,', 'functionalism:', 'time.', 'servicemen', 'pursue', 'ridiculous', 'decided', 'equals', 'appreciated.', 'reigns', 'beneficial', 'touches', 'freedom,', 'socially,', 'demise.', 'tell', 'sexuality,', 'great', 'whose', 'addition,', 'mass.', 'specific', "`conversation'", 'own,', 'surely', 'eternity', 'dog', 'label', 'embedded', 'withdrawing', 'common', 'words', 'prospect', 'society:', 'cock,', 'flaming', 'mob,', 'co ...
# scum as NLTK Text Object = <Text: tthe scum manifesto by valerie solanas [editor's notes]...>
# /Users/aluisek/Desktop/Github/Ace-Research/projectPython/.venv/lib/python3.12/site-packages/nltk/draw/__init__.py:15: UserWarning: nltk.draw package not loaded (please install Tkinter library).
#   warnings.warn("nltk.draw package not loaded (please install Tkinter library).")
