# %%
import spacy

#nlp = spacy.cli.download("en_core_web_lg")
nlp = spacy.load("en_core_web_lg")
#filepath = 'doc_analysis/aceAnger_full_album.txt'
#f = open(filepath, 'r', encoding='utf8').read()

# %%
import os
collection = 'doc_analysis'
def readTextFiles(filepath):
    with open(filepath, 'r', encoding='utf8') as f:
    # ebb: add that utf8 encoding argument to the open() function to ensure that reading works on everyone's systems
    # this all succeeds if you see the text of your files printed in the console.
        readFile = f.read()
        # print(readFile)
        stringFile = str(readFile)
        lengthFile = len(readFile)
        # (Literally, we'll just count the number of characters in this.)
        print(lengthFile)

for file in os.listdir(collection):
    if file.endswith(".txt"):
        filepath = f"{collection}/{file}"
        print(filepath)
        readTextFiles(filepath)

# %% [markdown]
# def readTextFiles(filepath):
#     with open(filepath, 'r', encoding='utf8') as f:
#         readFile = f.read()
#         # print(readFile)
#         stringFile = str(readFile)
#
#         tokens = nlp(stringFile)
#         # playing with vectors here
#         vectors = tokens.vector
#         # Want to "see" some vector information? Uncomment the  next line:
#         print(vectors)
#
# for file in os.listdir(collection):
#     if file.endswith(".txt"):
#         filepath = f"{collection}/{file}"
#         readTextFiles(filepath)def readTextFiles(filepath):
#     with open(filepath, 'r', encoding='utf8') as f:
#         readFile = f.read()
#         # print(readFile)
#         stringFile = str(readFile)
#
#         tokens = nlp(stringFile)
#         # playing with vectors here
#         vectors = tokens.vector
#         # Want to "see" some vector information? Uncomment the  next line:
#         # print(vectors)
#
#         wordOfInterest = nlp(u'asexual')
#
#          # Now, let's open an empty dictionary! We'll fill it up with the for loop just after it.
#         # The for-loop goes over each token and gets its values
#         highSimilarityDict = {}
#         for token in tokens:
#             if(token and token.vector_norm):
#                 if wordOfInterest.similarity(token) > .4:
#                 # ^^^^ our "similarity gage" ^^^^
#                     highSimilarityDict[token] = wordOfInterest.similarity(token)
#                     # The line above creates the structure for each entry in my dictionary.
#                         # print(token.text, "about this much similar to", wordOfInterest, ": ", wordOfInterest.similarity(token))
#         print(f'This is a dictionary of words most similar to the word "{wordOfInterest.text}" in "{file}".')
#         print(highSimilarityDict)
#         print('\n')
#
#
#
# for file in os.listdir(collection):
#     if file.endswith(".txt"):
#         filepath = f"{collection}/{file}"
#         readTextFiles(filepath)

# %% [markdown]
# dictionary of words similar to asexual

# %%
def readTextFiles(filepath):
    with open(filepath, 'r', encoding='utf8') as f:
        readFile = f.read()
        # print(readFile)
        stringFile = str(readFile)

        tokens = nlp(stringFile)
        # playing with vectors here
        vectors = tokens.vector
        # Want to "see" some vector information? Uncomment the  next line:
        # print(vectors)

        wordOfInterest = nlp(u'asexual')

         # Now, let's open an empty dictionary! We'll fill it up with the for loop just after it.
        # The for-loop goes over each token and gets its values
        highSimilarityDict = {}
        for token in tokens:
            if(token and token.vector_norm):
                if wordOfInterest.similarity(token) > .4:
                # ^^^^ our "similarity gage" ^^^^
                    highSimilarityDict[token] = wordOfInterest.similarity(token)
                    # The line above creates the structure for each entry in my dictionary.
                        # print(token.text, "about this much similar to", wordOfInterest, ": ", wordOfInterest.similarity(token))
        print(f'This is a dictionary of words most similar to the word "{wordOfInterest.text}" in "{file}".')
        print(highSimilarityDict)
        print('\n')

        

for file in os.listdir(collection):
    if file.endswith(".txt"):
        filepath = f"{collection}/{file}"
        readTextFiles(filepath)

# %%
from collections import Counter

def readTextFiles(filepath):
    with open(filepath, 'r', encoding='utf8') as f:
        readFile = f.read()
        # print(readFile)
        stringFile = str(readFile)

        tokens = nlp(stringFile)
        # playing with vectors here
        vectors = tokens.vector
        # Want to "see" some vector information? Uncomment the  next line:
        # print(vectors)

        wordOfInterest = nlp(u'asexual')

        # Our structures for storing similarity data:
        # This time we'll add counts, 
        # and we'll use Python's sorted() function to sort by similarity values from high (close to 1) to low (close to 0):
        highSimilarityDict = {}
        sorted_similarity = sorted(highSimilarityDict.items(), key=lambda item: item[1], reverse=True)
        wordCounts = Counter()
        
        for token in tokens:
            if(token and token.vector_norm):
                if wordOfInterest.similarity(token) > .4:
                    wordCounts[token.text] += 1
                # ^^^^ our "similarity gage" ^^^^
                    highSimilarityDict[token] = wordOfInterest.similarity(token)
                    # The line above creates the structure for each entry in my dictionary.
                        # print(token.text, "about this much similar to", wordOfInterest, ": ", wordOfInterest.similarity(token))
        # Smoke test for the Counter(): 
        # for word, count in list(wordCounts.items())[:5]:
        #    print(f"'{word}': {count}")
        print(f'This is a dictionary of words most similar to the word "{wordOfInterest.text}" in "{file}".')
        for word, similarity in highSimilarityDict.items():
            count = wordCounts[word.text]
            print(f"{word}: similarity={similarity:.3f}, count={count}")
            # The `:3f` above basically just reduces the decimal places to three (as in 3 floating points). 
            # print(f"{word}: similarity={similarity}, count={count}")
        print('\n')
 

for file in os.listdir(collection):
    if file.endswith(".txt"):
        filepath = f"{collection}/{file}"
        readTextFiles(filepath)

# %%
import pandas as pd
import os
nlp = spacy.load("en_core_web_lg")

collection = 'doc_analysis'

def wordCollector(words, unit):
    wordList = []
    nodeAtts = []
    unitList = []
    for token in words:
        if token.pos_ == "ADJ":
            wordList.append(token.lemma_)
            nodeAtts.append(token.pos_)
            unitList.append(unit)

    data = {
        'word': wordList,
        'nodeType': nodeAtts,
        'unit': unitList
    }
    df = pd.DataFrame(data)
    return df
    # This is returning a separate dataframe for every source text file. 

# We need to consolidate all the dataframes into one file. Collect all dataframes here!
allDataFrames = []

for file in os.listdir(collection):
    if file.endswith(".txt"):
        filepath = f"{collection}/{file}"
        name, extension = os.path.splitext(file)
        with open(filepath, 'r', encoding='utf8') as f:
            readFile = f.read()
            spacyRead = nlp(readFile)
            myDataFrame = wordCollector(spacyRead, name)
            # Add each individual dataframe as it comes out into the list of dataframes!
            allDataFrames.append(myDataFrame)

# Make an output filepath
outputFilePath = 'mass-data.tsv'
# Turn the list of dataframes into one dataframe:
fullDataFrame = pd.concat(allDataFrames, ignore_index=True)
# print(fullDataFrame)

# Note, since Pandas knows how to open and write files line by line, we can skip that open() step we used last time.
fullDataFrame.to_csv(outputFilePath, sep='\t', index=False)
print('I just saved a dataframe as a TSV file.')
# Go check your filestash for the file.

# %%
import pandas as pd
import os
nlp = spacy.load("en_core_web_lg")

collection = 'doc_analysis'

for file in os.listdir(collection):
    if file.endswith(".txt"):
        filepath = f"{collection}/{file}"
        name, extension = os.path.splitext(file)
        print(name)
        with open(filepath, 'r', encoding='utf8') as f:
            readFile = f.read()
            spacyRead = nlp(readFile)
            for token in spacyRead:
                print(token.text, "---->", token.pos_, ":::::", token.lemma_)

# %%
import pandas as pd
import os
nlp = spacy.load("en_core_web_lg")

collection = 'doc_analysis'

def wordCollector(words, unit):
    wordList = []
    for token in words:
        if token.pos_ == "ADJ":
            wordList.append((token.lemma_, unit))
    uniqueLems = set(wordList)
    return uniqueLems

for file in os.listdir(collection):
    if file.endswith(".txt"):
        filepath = f"{collection}/{file}"
        name, extension = os.path.splitext(file)
        with open(filepath, 'r', encoding='utf8') as f:
            readFile = f.read()
            spacyRead = nlp(readFile)
            myWords = wordCollector(spacyRead, name)
            print(myWords)

# %%
import pandas as pd
import os
nlp = spacy.load("en_core_web_lg")

collection = 'doc_analysis'
def wordCollector(words, unit):
    wordList = []
    nodeAtts = []
    unitList = []
    for token in words:
        if token.pos_ == "ADJ":
            wordList.append(token.lemma_)
            nodeAtts.append(token.pos_)
            unitList.append(unit)

    data = {
        'word': wordList,
        'nodeType': nodeAtts,
        'unit': unitList
    }
    df = pd.DataFrame(data)
    return df

for file in os.listdir(collection):
    if file.endswith(".txt"):
        filepath = f"{collection}/{file}"
        name, extension = os.path.splitext(file)
        with open(filepath, 'r', encoding='utf8') as f:
            readFile = f.read()
            spacyRead = nlp(readFile)
            myDataFrame = wordCollector(spacyRead, name)
            print(myDataFrame)

# %%
import pandas as pd
import nltk
from nltk.corpus import wordnet as wn
nlp = spacy.load("en_core_web_lg")

collection = 'doc_analysis'

def wordCollector(words, unit):
    wordList = []
    nodeAtts = []
    synsetCounts = []
    unitList = []
    for token in words:
        if token.pos_ == "ADJ":
            synsets = len(wn.synsets(token.lemma_))
            # We should be able to look up and count those synsets right here!          
            wordList.append(token.lemma_)
            nodeAtts.append(token.pos_)
            synsetCounts.append(synsets)
            unitList.append(unit)
                          
    data = {
        'word': wordList,
        'nodeType': nodeAtts,
        'synsetCount': synsetCounts,
        'unit': unitList
    }
    
    df = pd.DataFrame(data)
    # ebb: Let's simplify the TSV data: 
    # We want one line for each distinct word, and to COUNT the word occurrences in line with the other info on its synsets and unit. 
    # groupby helps with this in pandas:
    df = (df.groupby(['word', 'nodeType', 'synsetCount', 'unit'], as_index=False)
            .size()   # ebb: .size() will deliver the number of times a word is used in the file!
            .rename(columns={'size': 'count'})) # ebb: This gives you a new column for the count of the words in the file.
        # ebb: We can use that for the edge thickness: count of the times a word is used. Should simplify your network visualization!
    return df
    # This is returning a separate dataframe for every source text file. 

# We need to consolidate all the dataframes into one file. Collect all dataframes here!
allDataFrames = []

for file in os.listdir(collection):
    if file.endswith(".txt"):
        filepath = f"{collection}/{file}"
        name, extension = os.path.splitext(file)
        with open(filepath, 'r', encoding='utf8') as f:
            readFile = f.read()
            spacyRead = nlp(readFile)
            myDataFrame = wordCollector(spacyRead, name)
            # Add each individual dataframe as it comes out into the list of dataframes!
            allDataFrames.append(myDataFrame)

# Make an output filepath
outputFilePath = 'adj-data.tsv'
# Turn the list of dataframes into one dataframe:
fullDataFrame = pd.concat(allDataFrames, ignore_index=True)

# Note, since Pandas knows how to open and write files line by line, we can skip that open() step we used last time.
fullDataFrame.to_csv(outputFilePath, sep='\t', index=False)
print('I just saved a NEW dataframe as a NEW TSV file.')
# Go check your filestash for the file.

# %% [markdown]
# sucessful adjective counter:

# %%
import spacy
nlp = spacy.load("en_core_web_lg")
import os
f = open(filepath, 'r', encoding='utf8').read()

collection = 'doc_analysis'
def readTextFiles(filepath):
    with open(filepath, 'r', encoding='utf8') as f:
    # ebb: add that utf8 encoding argument to the open() function to ensure that reading works on everyone's systems
    # this all succeeds if you see the text of your files printed in the console.
        readFile = f.read()
        # print(readFile)
        stringFile = str(readFile)
        lengthFile = len(readFile)
        # (Literally, we'll just count the number of characters in this.)
        print(lengthFile)

for file in os.listdir(collection):
    if file.endswith(".txt"):
        filepath = f"{collection}/{file}"
        print(filepath)
        readTextFiles(filepath)

spacyRead = nlp(f)
for token in spacyRead:
    print(token.text, "---->", token.pos_, ":::::", token.lemma_)

def wordCollector(words):
    wordList = []
    count = 0
    for token in words:
        if token.pos_ == "ADJ":
            count += 1
            # print(count, ": ", token.text, " lemma: ", token.lemma_, " pos: ", token.pos_)
            # don't forget the underscore after token.lemma_ , token.pos_, etc.!
            wordList.append(token.lemma_)
            print(count, ": ", token, token.pos_)
    print(count, ": ", 'ADJ')
    return wordList
myWords = wordCollector(spacyRead)
print(myWords)
# Out:
# doc_analysis/psyExcerptCopy.txt
# 28598
# doc_analysis/black_moutain.txt
# 238
# doc_analysis/txt-counceling.txt
# 1232
# doc_analysis/Atrocity.txt
# 284
# doc_analysis/devolution.txt
# 339
# doc_analysis/txt-imp-malecopy.txt
# 151649
# doc_analysis/txt-militancy.txt
# 2273
# doc_analysis/53-year-old-virgin.txt
# 1054
# doc_analysis/txt-lack-of-desire.txt
# 8355
# doc_analysis/txt-freak.txt
# 1137
# doc_analysis/aceAnger_full_album.txt
# 1764
# doc_analysis/sex-lib-and-friendshipCopy.txt
# 21342
# doc_analysis/txt-fifth-estate.txt
# 1474
# doc_analysis/txt-aint-I-a-woman.txt
# 4603
# doc_analysis/txt-dismayed-parent.txt
# 2050
# doc_analysis/the-female-impersonators-transcript.txt
# 495690
# doc_analysis/txt-ace-auto.txt
# 29287
# doc_analysis/txt-own-label.txt
# 1611
# doc_analysis/aujeszky.txt
# 356
# doc_analysis/historically-stressed.txt
# 8256
# doc_analysis/gender-flex.txt
# 846
# doc_analysis/txt-limerance.txt
# 10725
# doc_analysis/txt-afraid-to-ask.txt
# 2267
# doc_analysis/SCUMcopy.txt
# 68294
# doc_analysis/transvestiaCopy.txt
# 1111
# doc_analysis/aceChicCopy.txt
# 17092
# doc_analysis/betweenMentalhealthAndDesease copy2.txt
# 939
# doc_analysis/bit-o-worldCopy.txt
# 8118
# doc_analysis/txt-dear-abby.txt
# 1418
# doc_analysis/Song_asexualAnger.txt
# 337
# doc_analysis/something-more-than-friendshipCopy.txt
# 56051
# doc_analysis/txt-imp-femalecopy.txt
# 11667
# doc_analysis/infernal_spiral.txt
# 241
# doc_analysis/txt-dear-abby 2.txt
# 1418
#
#  ----> SPACE :::::
#
# Happy ----> PROPN ::::: Happy
# Celibates ----> PROPN ::::: Celibates
# Want ----> VERB ::::: want
# No ----> DET ::::: no
# Change ----> NOUN ::::: change
#
#
#  ----> SPACE :::::
#
#
# DEAR ----> ADJ ::::: dear
# ABBY ----> PROPN ::::: ABBY
# : ----> PUNCT ::::: :
# Recently ----> ADV ::::: recently
# you ----> PRON ::::: you
# wrote ----> VERB ::::: write
# , ----> PUNCT ::::: ,
# " ----> PUNCT ::::: "
# no ----> DET ::::: no
# healthy ----> ADJ ::::: healthy
# normal ----> ADJ ::::: normal
# man ----> NOUN ::::: man
# ( ----> PUNCT ::::: (
# or ----> CCONJ ::::: or
# woman ----> NOUN ::::: woman
# ) ----> PUNCT ::::: )
# is ----> AUX ::::: be
# supposed ----> VERB ::::: suppose
# to ----> PART ::::: to
# by ----> ADP ::::: by
# " ----> PUNCT ::::: "
# happy ----> ADJ ::::: happy
# " ----> PUNCT ::::: "
# in ----> ADP ::::: in
# abstinence ----> NOUN ::::: abstinence
# " ----> PUNCT ::::: "
# ( ----> PUNCT ::::: (
# from ----> ADP ::::: from
# an ----> DET ::::: an
# active ----> ADJ ::::: active
# sex ----> NOUN ::::: sex
# life ----> NOUN ::::: life
# ) ----> PUNCT ::::: )
# . ----> PUNCT ::::: .
#
#
#  ----> SPACE :::::
#
#
# I ----> PRON ::::: I
# hope ----> VERB ::::: hope
# you ----> PRON ::::: you
# will ----> AUX ::::: will
# rethink ----> VERB ::::: rethink
# you ----> PRON ::::: you
# position ----> NOUN ::::: position
# . ----> PUNCT ::::: .
# You ----> PRON ::::: you
# have ----> AUX ::::: have
# been ----> AUX ::::: be
# , ----> PUNCT ::::: ,
# over ----> ADP ::::: over
# the ----> DET ::::: the
# years ----> NOUN ::::: year
# , ----> PUNCT ::::: ,
# a ----> DET ::::: a
# great ----> ADJ ::::: great
# friend ----> NOUN ::::: friend
# of ----> ADP ::::: of
# hetero- ----> NOUN ::::: hetero-
# , ----> PUNCT ::::: ,
# homo- ----> NOUN ::::: homo-
# , ----> PUNCT ::::: ,
# and ----> CCONJ ::::: and
# even ----> ADV ::::: even
# bisexuals ----> NOUN ::::: bisexual
# . ----> PUNCT ::::: .
# How ----> SCONJ ::::: how
# about ----> ADP ::::: about
# a ----> DET ::::: a
# good ----> ADJ ::::: good
# word ----> NOUN ::::: word
# for ----> ADP ::::: for
# those ----> PRON ::::: those
# of ----> ADP ::::: of
# us ----> PRON ::::: we
# who ----> PRON ::::: who
# are ----> AUX ::::: be
# genuinely ----> ADV ::::: genuinely
# asexual ----> ADJ ::::: asexual
# ? ----> PUNCT ::::: ?
# We ----> PRON ::::: we
# are ----> AUX ::::: be
# truly ----> ADV ::::: truly
# a ----> DET ::::: a
# forgotten ----> VERB ::::: forget
# minority ----> NOUN ::::: minority
# . ----> PUNCT ::::: .
#
#
#  ----> SPACE :::::
#
#
# I ----> PRON ::::: I
# , ----> PUNCT ::::: ,
# for ----> ADP ::::: for
# one ----> NUM ::::: one
# , ----> PUNCT ::::: ,
# am ----> AUX ::::: be
# quite ----> ADV ::::: quite
# happy ----> ADJ ::::: happy
# without ----> ADP ::::: without
# sex ----> NOUN ::::: sex
# . ----> PUNCT ::::: .
# Personally ----> ADV ::::: personally
# , ----> PUNCT ::::: ,
# I ----> PRON ::::: I
# am ----> AUX ::::: be
# repelled ----> VERB ::::: repel
# by ----> ADP ::::: by
# sex ----> NOUN ::::: sex
# , ----> PUNCT ::::: ,
# although ----> SCONJ ::::: although
# I ----> PRON ::::: I
# am ----> AUX ::::: be
# heartily ----> ADV ::::: heartily
# in ----> ADP ::::: in
# favor ----> NOUN ::::: favor
# of ----> ADP ::::: of
# a ----> DET ::::: a
# happy ----> ADJ ::::: happy
# , ----> PUNCT ::::: ,
# normal ----> ADJ ::::: normal
# sex ----> NOUN ::::: sex
# life ----> NOUN ::::: life
# for ----> ADP ::::: for
# those ----> PRON ::::: those
# who ----> PRON ::::: who
# favor ----> VERB ::::: favor
# it ----> PRON ::::: it
# . ----> PUNCT ::::: .
# I ----> PRON ::::: I
# do ----> AUX ::::: do
# not ----> PART ::::: not
# want ----> VERB ::::: want
# to ----> PART ::::: to
# be ----> AUX ::::: be
# thought ----> VERB ::::: think
# of ----> ADP ::::: of
# as ----> ADP ::::: as
# " ----> PUNCT ::::: "
# unhealthy ----> ADJ ::::: unhealthy
# " ----> PUNCT ::::: "
# or ----> CCONJ ::::: or
# " ----> PUNCT ::::: "
# abnormal ----> ADJ ::::: abnormal
# . ----> PUNCT ::::: .
# " ----> PUNCT ::::: "
# I ----> PRON ::::: I
# am ----> AUX ::::: be
# living ----> VERB ::::: live
# in ----> ADP ::::: in
# the ----> DET ::::: the
# way ----> NOUN ::::: way
# that ----> PRON ::::: that
# is ----> AUX ::::: be
# right ----> ADJ ::::: right
# for ----> ADP ::::: for
# me ----> PRON ::::: I
# . ----> PUNCT ::::: .
# Unfortunately ----> ADV ::::: unfortunately
# , ----> PUNCT ::::: ,
# because ----> SCONJ ::::: because
# I ----> PRON ::::: I
# am ----> AUX ::::: be
# not ----> PART ::::: not
# married ----> ADJ ::::: married
# and ----> CCONJ ::::: and
# do ----> AUX ::::: do
# not ----> PART ::::: not
# have ----> VERB ::::: have
# a ----> DET ::::: a
# lover ----> NOUN ::::: lover
# , ----> PUNCT ::::: ,
# many ----> ADJ ::::: many
# people ----> NOUN ::::: people
# assume ----> VERB ::::: assume
# that ----> SCONJ ::::: that
# I ----> PRON ::::: I
# am ----> AUX ::::: be
# a ----> DET ::::: a
# lesbian ----> NOUN ::::: lesbian
# , ----> PUNCT ::::: ,
# which ----> PRON ::::: which
# I ----> PRON ::::: I
# definitely ----> ADV ::::: definitely
# am ----> AUX ::::: be
# not ----> PART ::::: not
# . ----> PUNCT ::::: .
#
#
#  ----> SPACE :::::
#
#
# Some ----> PRON ::::: some
# of ----> ADP ::::: of
# history ----> NOUN ::::: history
# 's ----> PART ::::: 's
# most ----> ADV ::::: most
# creative ----> ADJ ::::: creative
# people ----> NOUN ::::: people
# have ----> AUX ::::: have
# been ----> AUX ::::: be
# celibate ----> VERB ::::: celibate
# by ----> ADP ::::: by
# choice ----> NOUN ::::: choice
# . ----> PUNCT ::::: .
# Please ----> INTJ ::::: please
# think ----> VERB ::::: think
# about ----> ADP ::::: about
# it ----> PRON ::::: it
# , ----> PUNCT ::::: ,
# Abby ----> PROPN ::::: Abby
# , ----> PUNCT ::::: ,
# and ----> CCONJ ::::: and
# give ----> VERB ::::: give
# us ----> PRON ::::: we
# a ----> DET ::::: a
# break ----> NOUN ::::: break
# . ----> PUNCT ::::: .
#
#
#  ----> SPACE :::::
#
#
# AGE ----> PROPN ::::: AGE
# 42 ----> NUM ::::: 42
# AND ----> CCONJ ::::: and
# STILL ----> ADV ::::: still
# A ----> DET ::::: a
# VIRGIN ----> PROPN ::::: VIRGIN
#
#
#  ----> SPACE :::::
#
#
# DEAR ----> PROPN ::::: DEAR
# 42 ----> NUM ::::: 42
# : ----> PUNCT ::::: :
# To ----> ADP ::::: to
# each ----> DET ::::: each
# his ----> PRON ::::: his
# ( ----> PUNCT ::::: (
# or ----> CCONJ ::::: or
# her ----> PRON ::::: her
# ) ----> PUNCT ::::: )
# own ----> ADJ ::::: own
# . ----> PUNCT ::::: .
# Meet ----> VERB ::::: meet
# another ----> DET ::::: another
# happy ----> ADJ ::::: happy
# celibate ----> VERB ::::: celibate
# : ----> PUNCT ::::: :
#
#
#  ----> SPACE :::::
#
#
# DEAR ----> ADJ ::::: dear
# ABBY ----> PROPN ::::: ABBY
# : ----> PUNCT ::::: :
# I ----> PRON ::::: I
# must ----> AUX ::::: must
# object ----> VERB ::::: object
# to ----> ADP ::::: to
# your ----> PRON ::::: your
# comment ----> NOUN ::::: comment
# to ----> ADP ::::: to
# NO ----> DET ::::: no
# ACTION ----> NOUN ::::: action
# IN ----> ADP ::::: in
# WASHINGTON ----> PROPN ::::: WASHINGTON
# STATE ----> PROPN ::::: STATE
# . ----> PUNCT ::::: .
# You ----> PRON ::::: you
# said ----> VERB ::::: say
# : ----> PUNCT ::::: :
# " ----> PUNCT ::::: "
# No ----> DET ::::: no
# healthy ----> ADJ ::::: healthy
# normal ----> ADJ ::::: normal
# man ----> NOUN ::::: man
# ( ----> PUNCT ::::: (
# or ----> CCONJ ::::: or
# woman ----> NOUN ::::: woman
# ) ----> PUNCT ::::: )
# is ----> AUX ::::: be
# supposed ----> VERB ::::: suppose
# to ----> PART ::::: to
# be ----> AUX ::::: be
# ' ----> PUNCT ::::: '
# happy ----> ADJ ::::: happy
# ' ----> PUNCT ::::: '
# in ----> ADP ::::: in
# abstinence ----> NOUN ::::: abstinence
# . ----> PUNCT ::::: .
# " ----> PUNCT ::::: "
#
#
#  ----> SPACE :::::
#
#
# I ----> PRON ::::: I
# consider ----> VERB ::::: consider
# myself ----> PRON ::::: myself
# a ----> DET ::::: a
# happy ----> ADJ ::::: happy
# , ----> PUNCT ::::: ,
# normal ----> ADJ ::::: normal
# , ----> PUNCT ::::: ,
# healthy ----> ADJ ::::: healthy
# male ----> NOUN ::::: male
# , ----> PUNCT ::::: ,
# and ----> CCONJ ::::: and
# abstinence ----> NOUN ::::: abstinence
# is ----> AUX ::::: be
# my ----> PRON ::::: my
# choice ----> NOUN ::::: choice
# . ----> PUNCT ::::: .
# As ----> ADP ::::: as
# a ----> DET ::::: a
# matter ----> NOUN ::::: matter
# of ----> ADP ::::: of
# fact ----> NOUN ::::: fact
# , ----> PUNCT ::::: ,
# like ----> ADP ::::: like
# thousands ----> NOUN ::::: thousand
# of ----> ADP ::::: of
# others ----> NOUN ::::: other
# who ----> PRON ::::: who
# have ----> AUX ::::: have
# taken ----> VERB ::::: take
# the ----> DET ::::: the
# vow ----> NOUN ::::: vow
# of ----> ADP ::::: of
# celibacy ----> NOUN ::::: celibacy
# , ----> PUNCT ::::: ,
# I ----> PRON ::::: I
# feel ----> VERB ::::: feel
# that ----> SCONJ ::::: that
# for ----> ADP ::::: for
# me ----> PRON ::::: I
# , ----> PUNCT ::::: ,
# celibacy ----> NOUN ::::: celibacy
# is ----> AUX ::::: be
# an ----> DET ::::: an
# important ----> ADJ ::::: important
# part ----> NOUN ::::: part
# of ----> ADP ::::: of
# my ----> PRON ::::: my
# life ----> NOUN ::::: life
# . ----> PUNCT ::::: .
# Sign ----> VERB ::::: sign
# me ----> PRON ::::: I
# , ----> PUNCT ::::: ,
# HAPPILY ----> ADV ::::: happily
# CELIBATE ----> VERB ::::: CELIBATE
# IN ----> ADP ::::: in
# N.Y. ----> PROPN ::::: N.Y.
#
#  ----> SPACE :::::
#
# 1 :  DEAR ADJ
# 2 :  healthy ADJ
# 3 :  normal ADJ
# 4 :  happy ADJ
# 5 :  active ADJ
# 6 :  great ADJ
# 7 :  good ADJ
# 8 :  asexual ADJ
# 9 :  happy ADJ
# 10 :  happy ADJ
# 11 :  normal ADJ
# 12 :  unhealthy ADJ
# 13 :  abnormal ADJ
# 14 :  right ADJ
# 15 :  married ADJ
# 16 :  many ADJ
# 17 :  creative ADJ
# 18 :  own ADJ
# 19 :  happy ADJ
# 20 :  DEAR ADJ
# 21 :  healthy ADJ
# 22 :  normal ADJ
# 23 :  happy ADJ
# 24 :  happy ADJ
# 25 :  normal ADJ
# 26 :  healthy ADJ
# 27 :  important ADJ
# 27 :  ADJ
# ['dear', 'healthy', 'normal', 'happy', 'active', 'great', 'good', 'asexual', 'happy', 'happy', 'normal', 'unhealthy', 'abnormal', 'right', 'married', 'many', 'creative', 'own', 'happy', 'dear', 'healthy', 'normal', 'happy', 'happy', 'normal', 'healthy', 'important']

# %%
from collections import Counter
import nltk
from nltk.corpus import wordnet as wn
import os
collection = 'doc_analysis'


word_freq = Counter(myWords)
#most_common() 
#converts the Counter's dictionary to a tuple series and sorts it
ranked = word_freq.most_common()
print(ranked)
topTen = word_freq.most_common()[:10]
# Hey DIGIT 210! This is called slicing a list! You're taking the first 10 or 20 items from the list
# you can also stick the 10 in most_common(10), to get the first ten entries. 

# Try uncommenting these others to see how they go:
print(topTen)
#lastTen = word_freq.most_common()[:-21:-1]
# This is slicing off the END of the list the bottom 20. 
# print(lastTen)
# Out:
# [('happy', 6), ('normal', 4), ('healthy', 3), ('dear', 2), ('active', 1), ('great', 1), ('good', 1), ('asexual', 1), ('unhealthy', 1), ('abnormal', 1), ('right', 1), ('married', 1), ('many', 1), ('creative', 1), ('own', 1), ('important', 1)]
# [('happy', 6), ('normal', 4), ('healthy', 3), ('dear', 2), ('active', 1), ('great', 1), ('good', 1), ('asexual', 1), ('unhealthy', 1), ('abnormal', 1)]

# %%
o = open("outPut/adjFreq.txt", "w")
# ebb: on the next line, notice how we enumerate over the whole tuple: 
# the first variable will give us a position number, commonly known as an "index" called i.
for i, t in enumerate(ranked):
    o.write(str(i) + str(t) + "\n")

# %%
import pygal
from pygal.style import DarkColorizedStyle

# There are lots of chart types in pygal. Bar is a nice simple one:
bar_chart = pygal.Bar(style=DarkColorizedStyle)
bar_chart.title = 'Top 10 Most Frequent Adjectives in the Asexual Database'

# Add data to the chart
for word, freq in topTen:
    bar_chart.add(word, freq)

# Render to file (SVG format)
bar_chart.render_to_file('top10_adj.svg')

# %% [markdown]
#  I'm gonna do verb frequency now

# %%
import spacy
nlp = spacy.load("en_core_web_lg")
import os
f = open(filepath, 'r', encoding='utf8').read()

collection = 'doc_analysis'
def readTextFiles(filepath):
    with open(filepath, 'r', encoding='utf8') as f:
    # ebb: add that utf8 encoding argument to the open() function to ensure that reading works on everyone's systems
    # this all succeeds if you see the text of your files printed in the console.
        readFile = f.read()
        # print(readFile)
        stringFile = str(readFile)
        lengthFile = len(readFile)
        # (Literally, we'll just count the number of characters in this.)
        print(lengthFile)

for file in os.listdir(collection):
    if file.endswith(".txt"):
        filepath = f"{collection}/{file}"
        print(filepath)
        readTextFiles(filepath)

spacyRead = nlp(f)
for token in spacyRead:
    print(token.text, "---->", token.pos_, ":::::", token.lemma_)

def wordCollector(words):
    wordList = []
    count = 0
    for token in words:
        if token.pos_ == "VERB":
            count += 1
            # print(count, ": ", token.text, " lemma: ", token.lemma_, " pos: ", token.pos_)
            # don't forget the underscore after token.lemma_ , token.pos_, etc.!
            wordList.append(token.lemma_)
            print(count, ": ", token, token.pos_)
    #print(count, ": ", 'ADJ')
    return wordList
myWords = wordCollector(spacyRead)
print(myWords)
# Out:
# doc_analysis/psyExcerptCopy.txt
# 28598
# doc_analysis/black_moutain.txt
# 238
# doc_analysis/txt-counceling.txt
# 1232
# doc_analysis/Atrocity.txt
# 284
# doc_analysis/devolution.txt
# 339
# doc_analysis/txt-imp-malecopy.txt
# 151649
# doc_analysis/txt-militancy.txt
# 2273
# doc_analysis/53-year-old-virgin.txt
# 1054
# doc_analysis/txt-lack-of-desire.txt
# 8355
# doc_analysis/txt-freak.txt
# 1137
# doc_analysis/aceAnger_full_album.txt
# 1764
# doc_analysis/sex-lib-and-friendshipCopy.txt
# 21342
# doc_analysis/txt-fifth-estate.txt
# 1474
# doc_analysis/txt-aint-I-a-woman.txt
# 4603
# doc_analysis/txt-dismayed-parent.txt
# 2050
# doc_analysis/the-female-impersonators-transcript.txt
# 495690
# doc_analysis/txt-ace-auto.txt
# 29287
# doc_analysis/txt-own-label.txt
# 1611
# doc_analysis/aujeszky.txt
# 356
# doc_analysis/historically-stressed.txt
# 8256
# doc_analysis/gender-flex.txt
# 846
# doc_analysis/txt-limerance.txt
# 10725
# doc_analysis/txt-afraid-to-ask.txt
# 2267
# doc_analysis/SCUMcopy.txt
# 68294
# doc_analysis/transvestiaCopy.txt
# 1111
# doc_analysis/aceChicCopy.txt
# 17092
# doc_analysis/betweenMentalhealthAndDesease copy2.txt
# 939
# doc_analysis/bit-o-worldCopy.txt
# 8118
# doc_analysis/txt-dear-abby.txt
# 1418
# doc_analysis/Song_asexualAnger.txt
# 337
# doc_analysis/something-more-than-friendshipCopy.txt
# 56051
# doc_analysis/txt-imp-femalecopy.txt
# 11667
# doc_analysis/infernal_spiral.txt
# 241
# doc_analysis/txt-dear-abby 2.txt
# 1418
#
#  ----> SPACE :::::
#
# Happy ----> PROPN ::::: Happy
# Celibates ----> PROPN ::::: Celibates
# Want ----> VERB ::::: want
# No ----> DET ::::: no
# Change ----> NOUN ::::: change
#
#
#  ----> SPACE :::::
#
#
# DEAR ----> ADJ ::::: dear
# ABBY ----> PROPN ::::: ABBY
# : ----> PUNCT ::::: :
# Recently ----> ADV ::::: recently
# you ----> PRON ::::: you
# wrote ----> VERB ::::: write
# , ----> PUNCT ::::: ,
# " ----> PUNCT ::::: "
# no ----> DET ::::: no
# healthy ----> ADJ ::::: healthy
# normal ----> ADJ ::::: normal
# man ----> NOUN ::::: man
# ( ----> PUNCT ::::: (
# or ----> CCONJ ::::: or
# woman ----> NOUN ::::: woman
# ) ----> PUNCT ::::: )
# is ----> AUX ::::: be
# supposed ----> VERB ::::: suppose
# to ----> PART ::::: to
# by ----> ADP ::::: by
# " ----> PUNCT ::::: "
# happy ----> ADJ ::::: happy
# " ----> PUNCT ::::: "
# in ----> ADP ::::: in
# abstinence ----> NOUN ::::: abstinence
# " ----> PUNCT ::::: "
# ( ----> PUNCT ::::: (
# from ----> ADP ::::: from
# an ----> DET ::::: an
# active ----> ADJ ::::: active
# sex ----> NOUN ::::: sex
# life ----> NOUN ::::: life
# ) ----> PUNCT ::::: )
# . ----> PUNCT ::::: .
#
#
#  ----> SPACE :::::
#
#
# I ----> PRON ::::: I
# hope ----> VERB ::::: hope
# you ----> PRON ::::: you
# will ----> AUX ::::: will
# rethink ----> VERB ::::: rethink
# you ----> PRON ::::: you
# position ----> NOUN ::::: position
# . ----> PUNCT ::::: .
# You ----> PRON ::::: you
# have ----> AUX ::::: have
# been ----> AUX ::::: be
# , ----> PUNCT ::::: ,
# over ----> ADP ::::: over
# the ----> DET ::::: the
# years ----> NOUN ::::: year
# , ----> PUNCT ::::: ,
# a ----> DET ::::: a
# great ----> ADJ ::::: great
# friend ----> NOUN ::::: friend
# of ----> ADP ::::: of
# hetero- ----> NOUN ::::: hetero-
# , ----> PUNCT ::::: ,
# homo- ----> NOUN ::::: homo-
# , ----> PUNCT ::::: ,
# and ----> CCONJ ::::: and
# even ----> ADV ::::: even
# bisexuals ----> NOUN ::::: bisexual
# . ----> PUNCT ::::: .
# How ----> SCONJ ::::: how
# about ----> ADP ::::: about
# a ----> DET ::::: a
# good ----> ADJ ::::: good
# word ----> NOUN ::::: word
# for ----> ADP ::::: for
# those ----> PRON ::::: those
# of ----> ADP ::::: of
# us ----> PRON ::::: we
# who ----> PRON ::::: who
# are ----> AUX ::::: be
# genuinely ----> ADV ::::: genuinely
# asexual ----> ADJ ::::: asexual
# ? ----> PUNCT ::::: ?
# We ----> PRON ::::: we
# are ----> AUX ::::: be
# truly ----> ADV ::::: truly
# a ----> DET ::::: a
# forgotten ----> VERB ::::: forget
# minority ----> NOUN ::::: minority
# . ----> PUNCT ::::: .
#
#
#  ----> SPACE :::::
#
#
# I ----> PRON ::::: I
# , ----> PUNCT ::::: ,
# for ----> ADP ::::: for
# one ----> NUM ::::: one
# , ----> PUNCT ::::: ,
# am ----> AUX ::::: be
# quite ----> ADV ::::: quite
# happy ----> ADJ ::::: happy
# without ----> ADP ::::: without
# sex ----> NOUN ::::: sex
# . ----> PUNCT ::::: .
# Personally ----> ADV ::::: personally
# , ----> PUNCT ::::: ,
# I ----> PRON ::::: I
# am ----> AUX ::::: be
# repelled ----> VERB ::::: repel
# by ----> ADP ::::: by
# sex ----> NOUN ::::: sex
# , ----> PUNCT ::::: ,
# although ----> SCONJ ::::: although
# I ----> PRON ::::: I
# am ----> AUX ::::: be
# heartily ----> ADV ::::: heartily
# in ----> ADP ::::: in
# favor ----> NOUN ::::: favor
# of ----> ADP ::::: of
# a ----> DET ::::: a
# happy ----> ADJ ::::: happy
# , ----> PUNCT ::::: ,
# normal ----> ADJ ::::: normal
# sex ----> NOUN ::::: sex
# life ----> NOUN ::::: life
# for ----> ADP ::::: for
# those ----> PRON ::::: those
# who ----> PRON ::::: who
# favor ----> VERB ::::: favor
# it ----> PRON ::::: it
# . ----> PUNCT ::::: .
# I ----> PRON ::::: I
# do ----> AUX ::::: do
# not ----> PART ::::: not
# want ----> VERB ::::: want
# to ----> PART ::::: to
# be ----> AUX ::::: be
# thought ----> VERB ::::: think
# of ----> ADP ::::: of
# as ----> ADP ::::: as
# " ----> PUNCT ::::: "
# unhealthy ----> ADJ ::::: unhealthy
# " ----> PUNCT ::::: "
# or ----> CCONJ ::::: or
# " ----> PUNCT ::::: "
# abnormal ----> ADJ ::::: abnormal
# . ----> PUNCT ::::: .
# " ----> PUNCT ::::: "
# I ----> PRON ::::: I
# am ----> AUX ::::: be
# living ----> VERB ::::: live
# in ----> ADP ::::: in
# the ----> DET ::::: the
# way ----> NOUN ::::: way
# that ----> PRON ::::: that
# is ----> AUX ::::: be
# right ----> ADJ ::::: right
# for ----> ADP ::::: for
# me ----> PRON ::::: I
# . ----> PUNCT ::::: .
# Unfortunately ----> ADV ::::: unfortunately
# , ----> PUNCT ::::: ,
# because ----> SCONJ ::::: because
# I ----> PRON ::::: I
# am ----> AUX ::::: be
# not ----> PART ::::: not
# married ----> ADJ ::::: married
# and ----> CCONJ ::::: and
# do ----> AUX ::::: do
# not ----> PART ::::: not
# have ----> VERB ::::: have
# a ----> DET ::::: a
# lover ----> NOUN ::::: lover
# , ----> PUNCT ::::: ,
# many ----> ADJ ::::: many
# people ----> NOUN ::::: people
# assume ----> VERB ::::: assume
# that ----> SCONJ ::::: that
# I ----> PRON ::::: I
# am ----> AUX ::::: be
# a ----> DET ::::: a
# lesbian ----> NOUN ::::: lesbian
# , ----> PUNCT ::::: ,
# which ----> PRON ::::: which
# I ----> PRON ::::: I
# definitely ----> ADV ::::: definitely
# am ----> AUX ::::: be
# not ----> PART ::::: not
# . ----> PUNCT ::::: .
#
#
#  ----> SPACE :::::
#
#
# Some ----> PRON ::::: some
# of ----> ADP ::::: of
# history ----> NOUN ::::: history
# 's ----> PART ::::: 's
# most ----> ADV ::::: most
# creative ----> ADJ ::::: creative
# people ----> NOUN ::::: people
# have ----> AUX ::::: have
# been ----> AUX ::::: be
# celibate ----> VERB ::::: celibate
# by ----> ADP ::::: by
# choice ----> NOUN ::::: choice
# . ----> PUNCT ::::: .
# Please ----> INTJ ::::: please
# think ----> VERB ::::: think
# about ----> ADP ::::: about
# it ----> PRON ::::: it
# , ----> PUNCT ::::: ,
# Abby ----> PROPN ::::: Abby
# , ----> PUNCT ::::: ,
# and ----> CCONJ ::::: and
# give ----> VERB ::::: give
# us ----> PRON ::::: we
# a ----> DET ::::: a
# break ----> NOUN ::::: break
# . ----> PUNCT ::::: .
#
#
#  ----> SPACE :::::
#
#
# AGE ----> PROPN ::::: AGE
# 42 ----> NUM ::::: 42
# AND ----> CCONJ ::::: and
# STILL ----> ADV ::::: still
# A ----> DET ::::: a
# VIRGIN ----> PROPN ::::: VIRGIN
#
#
#  ----> SPACE :::::
#
#
# DEAR ----> PROPN ::::: DEAR
# 42 ----> NUM ::::: 42
# : ----> PUNCT ::::: :
# To ----> ADP ::::: to
# each ----> DET ::::: each
# his ----> PRON ::::: his
# ( ----> PUNCT ::::: (
# or ----> CCONJ ::::: or
# her ----> PRON ::::: her
# ) ----> PUNCT ::::: )
# own ----> ADJ ::::: own
# . ----> PUNCT ::::: .
# Meet ----> VERB ::::: meet
# another ----> DET ::::: another
# happy ----> ADJ ::::: happy
# celibate ----> VERB ::::: celibate
# : ----> PUNCT ::::: :
#
#
#  ----> SPACE :::::
#
#
# DEAR ----> ADJ ::::: dear
# ABBY ----> PROPN ::::: ABBY
# : ----> PUNCT ::::: :
# I ----> PRON ::::: I
# must ----> AUX ::::: must
# object ----> VERB ::::: object
# to ----> ADP ::::: to
# your ----> PRON ::::: your
# comment ----> NOUN ::::: comment
# to ----> ADP ::::: to
# NO ----> DET ::::: no
# ACTION ----> NOUN ::::: action
# IN ----> ADP ::::: in
# WASHINGTON ----> PROPN ::::: WASHINGTON
# STATE ----> PROPN ::::: STATE
# . ----> PUNCT ::::: .
# You ----> PRON ::::: you
# said ----> VERB ::::: say
# : ----> PUNCT ::::: :
# " ----> PUNCT ::::: "
# No ----> DET ::::: no
# healthy ----> ADJ ::::: healthy
# normal ----> ADJ ::::: normal
# man ----> NOUN ::::: man
# ( ----> PUNCT ::::: (
# or ----> CCONJ ::::: or
# woman ----> NOUN ::::: woman
# ) ----> PUNCT ::::: )
# is ----> AUX ::::: be
# supposed ----> VERB ::::: suppose
# to ----> PART ::::: to
# be ----> AUX ::::: be
# ' ----> PUNCT ::::: '
# happy ----> ADJ ::::: happy
# ' ----> PUNCT ::::: '
# in ----> ADP ::::: in
# abstinence ----> NOUN ::::: abstinence
# . ----> PUNCT ::::: .
# " ----> PUNCT ::::: "
#
#
#  ----> SPACE :::::
#
#
# I ----> PRON ::::: I
# consider ----> VERB ::::: consider
# myself ----> PRON ::::: myself
# a ----> DET ::::: a
# happy ----> ADJ ::::: happy
# , ----> PUNCT ::::: ,
# normal ----> ADJ ::::: normal
# , ----> PUNCT ::::: ,
# healthy ----> ADJ ::::: healthy
# male ----> NOUN ::::: male
# , ----> PUNCT ::::: ,
# and ----> CCONJ ::::: and
# abstinence ----> NOUN ::::: abstinence
# is ----> AUX ::::: be
# my ----> PRON ::::: my
# choice ----> NOUN ::::: choice
# . ----> PUNCT ::::: .
# As ----> ADP ::::: as
# a ----> DET ::::: a
# matter ----> NOUN ::::: matter
# of ----> ADP ::::: of
# fact ----> NOUN ::::: fact
# , ----> PUNCT ::::: ,
# like ----> ADP ::::: like
# thousands ----> NOUN ::::: thousand
# of ----> ADP ::::: of
# others ----> NOUN ::::: other
# who ----> PRON ::::: who
# have ----> AUX ::::: have
# taken ----> VERB ::::: take
# the ----> DET ::::: the
# vow ----> NOUN ::::: vow
# of ----> ADP ::::: of
# celibacy ----> NOUN ::::: celibacy
# , ----> PUNCT ::::: ,
# I ----> PRON ::::: I
# feel ----> VERB ::::: feel
# that ----> SCONJ ::::: that
# for ----> ADP ::::: for
# me ----> PRON ::::: I
# , ----> PUNCT ::::: ,
# celibacy ----> NOUN ::::: celibacy
# is ----> AUX ::::: be
# an ----> DET ::::: an
# important ----> ADJ ::::: important
# part ----> NOUN ::::: part
# of ----> ADP ::::: of
# my ----> PRON ::::: my
# life ----> NOUN ::::: life
# . ----> PUNCT ::::: .
# Sign ----> VERB ::::: sign
# me ----> PRON ::::: I
# , ----> PUNCT ::::: ,
# HAPPILY ----> ADV ::::: happily
# CELIBATE ----> VERB ::::: CELIBATE
# IN ----> ADP ::::: in
# N.Y. ----> PROPN ::::: N.Y.
#
#  ----> SPACE :::::
#
# 1 :  Want VERB
# 2 :  wrote VERB
# 3 :  supposed VERB
# 4 :  hope VERB
# 5 :  rethink VERB
# 6 :  forgotten VERB
# 7 :  repelled VERB
# 8 :  favor VERB
# 9 :  want VERB
# 10 :  thought VERB
# 11 :  living VERB
# 12 :  have VERB
# 13 :  assume VERB
# 14 :  celibate VERB
# 15 :  think VERB
# 16 :  give VERB
# 17 :  Meet VERB
# 18 :  celibate VERB
# 19 :  object VERB
# 20 :  said VERB
# 21 :  supposed VERB
# 22 :  consider VERB
# 23 :  taken VERB
# 24 :  feel VERB
# 25 :  Sign VERB
# 26 :  CELIBATE VERB
# ['want', 'write', 'suppose', 'hope', 'rethink', 'forget', 'repel', 'favor', 'want', 'think', 'live', 'have', 'assume', 'celibate', 'think', 'give', 'meet', 'celibate', 'object', 'say', 'suppose', 'consider', 'take', 'feel', 'sign', 'CELIBATE']

# %%
from collections import Counter
import nltk
from nltk.corpus import wordnet as wn
import os
collection = 'doc_analysis'


word_freq = Counter(myWords)
#most_common() 
#converts the Counter's dictionary to a tuple series and sorts it
ranked = word_freq.most_common()
print(ranked)
topTen = word_freq.most_common()[:10]
# Hey DIGIT 210! This is called slicing a list! You're taking the first 10 or 20 items from the list
# you can also stick the 10 in most_common(10), to get the first ten entries. 

# Try uncommenting these others to see how they go:
print(topTen)
#lastTen = word_freq.most_common()[:-21:-1]
# This is slicing off the END of the list the bottom 20.
# Out:
# [('want', 2), ('suppose', 2), ('think', 2), ('celibate', 2), ('write', 1), ('hope', 1), ('rethink', 1), ('forget', 1), ('repel', 1), ('favor', 1), ('live', 1), ('have', 1), ('assume', 1), ('give', 1), ('meet', 1), ('object', 1), ('say', 1), ('consider', 1), ('take', 1), ('feel', 1), ('sign', 1), ('CELIBATE', 1)]
# [('want', 2), ('suppose', 2), ('think', 2), ('celibate', 2), ('write', 1), ('hope', 1), ('rethink', 1), ('forget', 1), ('repel', 1), ('favor', 1)]

# %%
o = open("outPut/verbFreq.txt", "w")
# ebb: on the next line, notice how we enumerate over the whole tuple: 
# the first variable will give us a position number, commonly known as an "index" called i.
for i, t in enumerate(ranked):
    o.write(str(i) + str(t) + "\n")

# %%
import pygal
from pygal.style import DarkColorizedStyle

# There are lots of chart types in pygal. Bar is a nice simple one:
pie_chart = pygal.Pie(style=DarkColorizedStyle)
pie_chart.title = 'Top 10 Most Frequent Verbs in the Asexual Database'

# Add data to the chart
for word, freq in topTen:
    pie_chart.add(word, freq)

# Render to file (SVG format)
pie_chart.render_to_file('top10_verb.svg')
